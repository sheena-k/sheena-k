# %% [markdown]
# # Case Study on Data Preprocessing and Correlation Function

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading of dataset

# %%
data = pd.read_excel("E-commerce.xlsx")

# %%
data.columns
# Out:
# Index(['server_time', 'device_type', 'user_id', 'session_id', 'item_id',
#        'item_price', 'category', 'product_type', 'impression_time', 'app_code',
#        'os_version', 'is_4G', 'is_click'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2025 entries, 0 to 2024
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   server_time      2025 non-null   datetime64[ns]
#  1   device_type      2025 non-null   object
#  2   user_id          2022 non-null   float64
#  3   session_id       2024 non-null   float64
#  4   item_id          2023 non-null   float64
#  5   item_price       2024 non-null   float64
#  6   category         2019 non-null   float64
#  7   product_type     2024 non-null   float64
#  8   impression_time  2025 non-null   datetime64[ns]
#  9   app_code         2024 non-null   float64
#  10  os_version       2016 non-null   object
#  11  is_4G            2025 non-null   int64
#  12  is_click         2025 non-null   int64
# dtypes: datetime64[ns](2), float64(7), int64(2), object(2)
# memory usage: 205.8+ KB

# %%
data.shape
# Out:
# (2025, 13)

# %% [markdown]
# # Finding Null values

# %%
data.isna().sum()
# Out:
# server_time        0
# device_type        0
# user_id            3
# session_id         1
# item_id            2
# item_price         1
# category           6
# product_type       1
# impression_time    0
# app_code           1
# os_version         9
# is_4G              0
# is_click           0
# dtype: int64

# %%
data.describe()
# Out:
#             user_id    session_id        item_id     item_price     category  \
# count   2022.000000  2.024000e+03    2023.000000    2024.000000  2019.000000
# mean   46714.461919  5.473724e+05   63505.154721    6661.115119    10.290738
# std    26401.598808  3.108620e+05   36830.177344   17296.372880     4.961514
# min       10.000000  1.694000e+03     176.000000      16.000000     0.000000
# 25%    24853.000000  2.738070e+05   33845.500000    1465.000000     7.000000
# 50%    46248.000000  5.440370e+05   62896.000000    2425.000000    11.000000
# 75%    69375.500000  7.996875e+05   91322.000000    4793.000000    14.000000
# max    92508.000000  1.089219e+06  132865.000000  239360.000000    17.000000
#
#        product_type     app_code        is_4G     is_click
# count   2024.000000  2024.000000  2025.000000  2025.000000
# mean    5359.607213   244.741107     0.342222     0.049877
# std     3076.114288   124.477650     0.474571     0.217744
# ...

# %% [markdown]
# # Data Cleaning and filling Null values

# %%
data["user_id"].fillna(method='ffill', inplace= True)

# %%
data["session_id"].fillna(method='ffill', inplace= True)

# %%
data["item_id"].fillna(method='ffill', inplace= True)

# %%
data.isna().sum()
# Out:
# server_time        0
# device_type        0
# user_id            0
# session_id         0
# item_id            0
# item_price         1
# category           6
# product_type       1
# impression_time    0
# app_code           1
# os_version         9
# is_4G              0
# is_click           0
# dtype: int64

# %%
data['item_price'] =  data['item_price'].fillna( data['item_price'].median())

# %%
for i in ["category","product_type","os_version"]:
    data[i]= data[i].fillna(data[i].mode()[0])

# %%
data.isna().sum()
# Out:
# server_time        0
# device_type        0
# user_id            0
# session_id         0
# item_id            0
# item_price         0
# category           0
# product_type       0
# impression_time    0
# app_code           1
# os_version         0
# is_4G              0
# is_click           0
# dtype: int64

# %%
data["app_code"].fillna(method='ffill', inplace= True)

# %%
data.isna().sum()
# Out:
# server_time        0
# device_type        0
# user_id            0
# session_id         0
# item_id            0
# item_price         0
# category           0
# product_type       0
# impression_time    0
# app_code           0
# os_version         0
# is_4G              0
# is_click           0
# dtype: int64

# %% [markdown]
# # Data Encoding

# %% [markdown]
# **Label Encoding & One hot Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le= LabelEncoder()

# %%
data["device_type"].unique()
# Out:
# array(['android'], dtype=object)

# %%
df= pd.read_excel("E-commerce.xlsx")

# %%
df.head(20)
# Out:
#            server_time device_type  user_id  session_id   item_id  item_price  \
# 0  2018-10-18 14:27:00     android  87862.0    268465.0   44459.0      4602.0
# 1  2018-10-18 14:27:00     android  63410.0    268465.0   44459.0      3513.0
# 2  2018-10-18 14:43:00     android  71748.0    268465.0   44459.0       825.0
# 3  2018-10-18 14:46:00     android  69209.0    268465.0   44459.0      2355.0
# 4  2018-10-18 14:46:00     android  62873.0    268465.0   44459.0      1267.0
# 5  2018-10-18 14:47:00     android  67352.0    268465.0   44459.0       953.0
# 6  2018-10-22 09:48:00     android  64356.0    295495.0   40228.0     18118.0
# 7  2018-10-26 09:07:00     android  27329.0    675965.0   58320.0     17856.0
# 8  2018-10-26 09:08:00     android  83318.0    675965.0  129641.0      2868.0
# 9  2018-11-04 09:14:00     android  70206.0     63432.0   64835.0      4032.0
# 10 2018-11-05 08:06:00     android  74339.0    116569.0   27574.0      2183.0
# ...

# %%
df = pd.get_dummies(df)
df.head(20)
# Out:
#            server_time  user_id  session_id   item_id  item_price  category  \
# 0  2018-10-18 14:27:00  87862.0    268465.0   44459.0      4602.0      11.0
# 1  2018-10-18 14:27:00  63410.0    268465.0   44459.0      3513.0      12.0
# 2  2018-10-18 14:43:00  71748.0    268465.0   44459.0       825.0      17.0
# 3  2018-10-18 14:46:00  69209.0    268465.0   44459.0      2355.0      13.0
# 4  2018-10-18 14:46:00  62873.0    268465.0   44459.0      1267.0      17.0
# 5  2018-10-18 14:47:00  67352.0    268465.0   44459.0       953.0       9.0
# 6  2018-10-22 09:48:00  64356.0    295495.0   40228.0     18118.0      16.0
# 7  2018-10-26 09:07:00  27329.0    675965.0   58320.0     17856.0      16.0
# 8  2018-10-26 09:08:00  83318.0    675965.0  129641.0      2868.0       7.0
# 9  2018-11-04 09:14:00  70206.0     63432.0   64835.0      4032.0      17.0
# 10 2018-11-05 08:06:00  74339.0    116569.0   27574.0      2183.0      13.0
# ...

# %%
df.columns
# Out:
# Index(['server_time', 'user_id', 'session_id', 'item_id', 'item_price',
#        'category', 'product_type', 'impression_time', 'app_code', 'is_4G',
#        'is_click', 'device_type_android', 'os_version_intermediate',
#        'os_version_latest', 'os_version_old'],
#       dtype='object')

# %% [markdown]
# ** New columns added

# %%
df.shape
# Out:
# (2025, 15)

# %% [markdown]
# # Correlation among data variables

# %%
X = df[["category","product_type","item_price","user_id"]]

# %%
X.corr()
# Out:
#               category  product_type  item_price   user_id  product_type
# category      1.000000     -0.014132    0.050378 -0.021029     -0.014132
# product_type -0.014132      1.000000   -0.022924  0.007024      1.000000
# item_price    0.050378     -0.022924    1.000000  0.013286     -0.022924
# user_id      -0.021029      0.007024    0.013286  1.000000      0.007024
# product_type -0.014132      1.000000   -0.022924  0.007024      1.000000

# %%
sns.heatmap(X.corr(),annot = True)
plt.show()

# %% [markdown]
# **from above correlation among data variables are weak.
