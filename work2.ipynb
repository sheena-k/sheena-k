# %% [markdown]
# <a href="https://colab.research.google.com/github/sheena-k/sheena-k/blob/main/work2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #                                                                 **ASSIGNMENT ON PYTHON FOR DATA SCIENCE**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #Q1 Read the dataset to Python Environment

# %%
data = pd.read_excel("/content/iris.xls")
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #Q2 Display the Columns in the dataset.

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# #Q3 Calculate the mean of each Columns of data set

# %%
print(data.mean())
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64
# <ipython-input-9-333c16b2968c>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(data.mean())

# %% [markdown]
# #Q4 Null Value in dataset

# %%
data.isnull()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]
# No charts were generated by quickchart

# %% [markdown]
# #Q5 Meaningful Vizualisation

# %% [markdown]
# # Line Graph Of Flower Species Iris Virginica between Sepal width and Petal Length

# %%
data=data.head()
df= pd.DataFrame(data, columns=["SW","PL","Iris-virginica"])
df.plot(x="SW",y=["PL","Iris-virginica"], kind= "line", figsize=(9,9))
plt.xlabel("Sepal Width ")
plt.ylabel("Petal Length")
plt.show()

# %% [markdown]
# #Line Graph Of Flower Species Iris Setosa between Petal width and Petal Length

# %%
data=data.head()
df= pd.DataFrame(data, columns=["PW","PL","Iris-setosa"])
df.plot(x="PW",y=["PL","Iris-setosa"], kind= "line", figsize=(9,9))
plt.xlabel("Petal Width ")
plt.ylabel("Petal Length")
plt.show()

# %% [markdown]
# #Line Graph Of Flower Species Iris Versicolor between Sepal width and Sepal Length

# %%
data=data.head()
df= pd.DataFrame(data, columns=["SW","SL","Iris-versicolor"])
df.plot(x="SW",y=["SL","Iris-versicolor"], kind= "line", figsize=(9,9))
plt.xlabel("Sepal Width ")
plt.ylabel("Sepal Length")
plt.show()

# %% [markdown]
# #SCATTER PLOT

# %%
sns.pairplot(data)

# %% [markdown]
# #Barplot of Different Species and its Species Width

# %%
plt.bar(data["Classification"],data["SW"])
plt.title("DataSet of Iris Flower",c="g")
plt.xlabel("Species Classificiation",c="r")
plt.ylabel("Characteristics=Sepal Width",c="r")
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2],
#  [Text(0, 0, 'Iris-setosa'),
#   Text(1, 0, 'Iris-versicolor'),
#   Text(2, 0, 'Iris-virginica')])

# %% [markdown]
# # DENSITY GRAPH -PETAL WIDTH

# %%
data['PW'].plot.kde()
plt.xlabel("PETAL WIDTH",c="r")
# Out:
# Text(0.5, 0, 'PETAL WIDTH')
